# %% [markdown]
# Data Analytics Mid Bootcamp Project

# %% [markdown]
# Dataset Bollywood

# %% [markdown]
# # Read the three files into python as dataframes

# %%
import pandas as pd

# %%
actor = pd.read_csv('data/BollywoodActorRanking.csv')
director = pd.read_csv('data/BollywoodDirectorRanking.csv')
movie = pd.read_csv('data/BollywoodMovieDetail.csv')

print(list(actor.columns))
print(list(director.columns))
print(list(movie.columns))
# Out:
# ['actorId', 'actorName', 'movieCount', 'ratingSum', 'normalizedMovieRank', 'googleHits', 'normalizedGoogleRank', 'normalizedRating']
# ['directorId', 'directorName', 'movieCount', 'ratingSum', 'normalizedMovieRank', 'googleHits', 'normalizedGoogleRank', 'normalizedRating']
# ['imdbId', 'title', 'releaseYear', 'releaseDate', 'genre', 'writers', 'actors', 'directors', 'sequel', 'hitFlop']

# %%
# Show the DataFrame's shape.

print(actor.shape)
print(director.shape)
print(movie.shape)
# Out:
# (301, 8)
# (118, 8)
# (1284, 10)

# %%
actor.head()
# Out:
#    actorId         actorName  movieCount  ratingSum  normalizedMovieRank  \
# 0      373        Aamir Khan          11       1170              9.44862
# 1      374    Shah Rukh Khan          23       2000              7.55009
# 2      375       Salman Khan          36       2340              5.40217
# 3      376      Katrina Kaif          17       1640              8.48082
# 4      377  Deepika Padukone          16       1080              5.64674
#
#    googleHits  normalizedGoogleRank  normalizedRating
# 0     2460000               7.34283          10.00000
# 1     2670000               7.88458           9.22674
# 2     3490000              10.00000           9.20821
# 3     2120000               6.46570           8.94852
# 4     3000000               8.73591           8.62716

# %%
director.head()
# Out:
#    directorId     directorName  movieCount  ratingSum  normalizedMovieRank  \
# 0           1  Rajkumar Hirani           3        440             10.00000
# 1           2       Farah Khan           4        440              7.39474
# 2           3      Karan Johar           5        430              5.68947
# 3           4       Sajid Khan           4        350              5.79605
# 4           5     Rohit Shetty          10        950              6.32895
#
#    googleHits  normalizedGoogleRank  normalizedRating
# 0      146000               2.07796          10.00000
# 1     1060000               8.88317           8.78473
# 2     1050000               8.80872           7.10460
# 3      905000               7.72912           6.99780
# 4      437000               4.24461           6.83761

# %%
movie.head()
# Out:
#       imdbId                              title  releaseYear  releaseDate  \
# 0  tt0118578                             Albela         2001  20 Apr 2001
# 1  tt0169102  Lagaan: Once Upon a Time in India         2001  08 May 2002
# 2  tt0187279           Meri Biwi Ka Jawab Nahin         2004  02 Jul 2004
# 3  tt0222024             Hum Tumhare Hain Sanam         2002  24 May 2002
# 4  tt0227194                         One 2 Ka 4         2001  30 Mar 2001
#
#                          genre  \
# 0                      Romance
# 1  Adventure | Drama | Musical
# 2              Action | Comedy
# 3              Drama | Romance
# 4      Action | Comedy | Drama
#
#                                              writers  \
# 0  Honey Irani (screenplay) | Honey Irani (story)...
# 1  Ashutosh Gowariker (story) | Ashutosh Gowarike...
# 2                                                NaN
# 3  K.S. Adiyaman | Arun Kumar (assistant dialogue...
# 4  Sanjay Chhel | Raaj Kumar Dahima (screenplay) ...
#
# ...

# %%
director.head()
# Out:
#    directorId     directorName  movieCount  ratingSum  normalizedMovieRank  \
# 0           1  Rajkumar Hirani           3        440             10.00000
# 1           2       Farah Khan           4        440              7.39474
# 2           3      Karan Johar           5        430              5.68947
# 3           4       Sajid Khan           4        350              5.79605
# 4           5     Rohit Shetty          10        950              6.32895
#
#    googleHits  normalizedGoogleRank  normalizedRating
# 0      146000               2.07796          10.00000
# 1     1060000               8.88317           8.78473
# 2     1050000               8.80872           7.10460
# 3      905000               7.72912           6.99780
# 4      437000               4.24461           6.83761

# %% [markdown]
# #Standardize header names.

# %%
print("Lowercase version actor")
for column in actor.columns:
    print(column.lower())
# Out:
# Lowercase version actor
# actorid
# actorname
# moviecount
# ratingsum
# normalizedmovierank
# googlehits
# normalizedgooglerank
# normalizedrating

# %%
print("Lowercase version director")
for column in director.columns:
    print(column.lower())
# Out:
# Lowercase version director
# directorid
# directorname
# moviecount
# ratingsum
# normalizedmovierank
# googlehits
# normalizedgooglerank
# normalizedrating

# %%
print("Lowercase version movie")
for column in movie.columns:
    print(column.lower())
# Out:
# Lowercase version movie
# imdbid
# title
# releaseyear
# releasedate
# genre
# writers
# actors
# directors
# sequel
# hitflop

# %%
cols1 = []
for column in actor.columns:
    cols1.append(column.lower())
actor.columns = cols1

cols2 = []
for column in director.columns:
    cols2.append(column.lower())
director.columns = cols2

cols3 = []
for column in movie.columns:
    cols3.append(column.lower())
movie.columns = cols3

# %%
display(actor.head())
# Out:
#    actorid         actorname  moviecount  ratingsum  normalizedmovierank  \
# 0      373        Aamir Khan          11       1170              9.44862
# 1      374    Shah Rukh Khan          23       2000              7.55009
# 2      375       Salman Khan          36       2340              5.40217
# 3      376      Katrina Kaif          17       1640              8.48082
# 4      377  Deepika Padukone          16       1080              5.64674
#
#    googlehits  normalizedgooglerank  normalizedrating
# 0     2460000               7.34283          10.00000
# 1     2670000               7.88458           9.22674
# 2     3490000              10.00000           9.20821
# 3     2120000               6.46570           8.94852
# 4     3000000               8.73591           8.62716

# %%
display(director.head())
# Out:
#    directorid     directorname  moviecount  ratingsum  normalizedmovierank  \
# 0           1  Rajkumar Hirani           3        440             10.00000
# 1           2       Farah Khan           4        440              7.39474
# 2           3      Karan Johar           5        430              5.68947
# 3           4       Sajid Khan           4        350              5.79605
# 4           5     Rohit Shetty          10        950              6.32895
#
#    googlehits  normalizedgooglerank  normalizedrating
# 0      146000               2.07796          10.00000
# 1     1060000               8.88317           8.78473
# 2     1050000               8.80872           7.10460
# 3      905000               7.72912           6.99780
# 4      437000               4.24461           6.83761

# %%
display(movie.head())
# Out:
#       imdbid                              title  releaseyear  releasedate  \
# 0  tt0118578                             Albela         2001  20 Apr 2001
# 1  tt0169102  Lagaan: Once Upon a Time in India         2001  08 May 2002
# 2  tt0187279           Meri Biwi Ka Jawab Nahin         2004  02 Jul 2004
# 3  tt0222024             Hum Tumhare Hain Sanam         2002  24 May 2002
# 4  tt0227194                         One 2 Ka 4         2001  30 Mar 2001
#
#                          genre  \
# 0                      Romance
# 1  Adventure | Drama | Musical
# 2              Action | Comedy
# 3              Drama | Romance
# 4      Action | Comedy | Drama
#
#                                              writers  \
# 0  Honey Irani (screenplay) | Honey Irani (story)...
# 1  Ashutosh Gowariker (story) | Ashutosh Gowarike...
# 2                                                NaN
# 3  K.S. Adiyaman | Arun Kumar (assistant dialogue...
# 4  Sanjay Chhel | Raaj Kumar Dahima (screenplay) ...
#
# ...

# %% [markdown]
# #Handling missing values

# %%
actor.isna().sum()
# Out:
# actorid                   0
# actorname                 0
# moviecount                0
# ratingsum                 0
# normalizedmovierank       2
# googlehits                0
# normalizedgooglerank    112
# normalizedrating          0
# dtype: int64

# %% [markdown]
# #took mean of values instewad of dropping

# %%
actor['normalizedmovierank'].fillna(actor['normalizedmovierank'].median(), inplace=True)

# %%
actor['normalizedgooglerank'].fillna(actor['normalizedgooglerank'].median(), inplace=True)

# %%
director.isna().sum()
# Out:
# directorid              0
# directorname            1
# moviecount              0
# ratingsum               0
# normalizedmovierank     0
# googlehits              0
# normalizedgooglerank    0
# normalizedrating        0
# dtype: int64

# %%
movie.isna().sum()
# Out:
# imdbid           0
# title            0
# releaseyear      0
# releasedate     53
# genre            2
# writers        119
# actors           3
# directors        4
# sequel           3
# hitflop          0
# dtype: int64

# %%
movie.shape[0]
# Out:
# 1284

# %%
movie2 = movie.dropna()

# %%
display (actor)
# Out:
#      actorid         actorname  moviecount  ratingsum  normalizedmovierank  \
# 0        373        Aamir Khan          11       1170              9.44862
# 1        374    Shah Rukh Khan          23       2000              7.55009
# 2        375       Salman Khan          36       2340              5.40217
# 3        376      Katrina Kaif          17       1640              8.48082
# 4        377  Deepika Padukone          16       1080              5.64674
# ..       ...               ...         ...        ...                  ...
# 296      669       Achint Kaur           4         80              1.00000
# 297      670   Yuvika Chaudhry           5        100              1.00000
# 298      671      Pankaj Berry           5        100              1.00000
# 299      672      Varun Dhawan           0          0              2.36957
# 300      673     Nargis Fakhri           0          0              2.36957
#
#      googlehits  normalizedgooglerank  normalizedrating
# ...

# %%
display (director)
# Out:
#      directorid     directorname  moviecount  ratingsum  normalizedmovierank  \
# 0             1  Rajkumar Hirani           3        440             10.00000
# 1             2       Farah Khan           4        440              7.39474
# 2             3      Karan Johar           5        430              5.68947
# 3             4       Sajid Khan           4        350              5.79605
# 4             5     Rohit Shetty          10        950              6.32895
# ..          ...              ...         ...        ...                  ...
# 113         114     Shyam Ramsay           3         60              1.00000
# 114         115      Jag Mundhra           3         60              1.00000
# 115         116    Kalpana Lajmi           3         60              1.00000
# 116         117    Ajay Chandhok           4         80              1.00000
# 117         118      Puneet Sira           3         60              1.00000
#
# ...

# %%
display (movie2)
# Out:
#          imdbid                              title  releaseyear  releasedate  \
# 0     tt0118578                             Albela         2001  20 Apr 2001
# 1     tt0169102  Lagaan: Once Upon a Time in India         2001  08 May 2002
# 3     tt0222024             Hum Tumhare Hain Sanam         2002  24 May 2002
# 4     tt0227194                         One 2 Ka 4         2001  30 Mar 2001
# 5     tt0238936                             Devdas         2002  12 Jul 2002
# ...         ...                                ...          ...          ...
# 1275  tt3893476                              Spark         2014  10 Oct 2014
# 1276  tt4010306                          Jigariyaa         2014  10 Oct 2014
# 1277  tt4045666                Mumbai Delhi Mumbai         2014  05 Dec 2014
# 1278  tt4119196                  Love U Crazy Girl         2014  09 May 2014
# 1283  tt4228746                                Zid         2014  28 Nov 2014
#
#                             genre  \
# ...

# %%
movie2= movie2.drop(['sequel','releasedate'], axis=1)

# %%
display (movie2)
# Out:
#          imdbid                              title  releaseyear  \
# 0     tt0118578                             Albela         2001
# 1     tt0169102  Lagaan: Once Upon a Time in India         2001
# 3     tt0222024             Hum Tumhare Hain Sanam         2002
# 4     tt0227194                         One 2 Ka 4         2001
# 5     tt0238936                             Devdas         2002
# ...         ...                                ...          ...
# 1275  tt3893476                              Spark         2014
# 1276  tt4010306                          Jigariyaa         2014
# 1277  tt4045666                Mumbai Delhi Mumbai         2014
# 1278  tt4119196                  Love U Crazy Girl         2014
# 1283  tt4228746                                Zid         2014
#
#                             genre  \
# 0                         Romance
# 1     Adventure | Drama | Musical
# 3                 Drama | Romance
# 4         Action | Comedy | Drama
# ...

# %% [markdown]
# #looking which movie title has how many hit and flop

# %%
movie2[['title','hitflop']]
# Out:
#                                   title  hitflop
# 0                                Albela        2
# 1     Lagaan: Once Upon a Time in India        6
# 3                Hum Tumhare Hain Sanam        4
# 4                            One 2 Ka 4        1
# 5                                Devdas        6
# ...                                 ...      ...
# 1275                              Spark        1
# 1276                          Jigariyaa        1
# 1277                Mumbai Delhi Mumbai        1
# 1278                  Love U Crazy Girl        1
# 1283                                Zid        2
#
# [1131 rows x 2 columns]

# %% [markdown]
# # hit and flop movie data

# %%
movie2.sort_values('hitflop', ascending=False)
# Out:
#          imdbid                        title  releaseyear  \
# 901   tt1833673                     Dhoom: 3         2013
# 625   tt1187043                     3 Idiots         2009
# 32    tt0284137         Gadar: Ek Prem Katha         2001
# 1092  tt2338151                           PK         2014
# 863   tt1729637                    Bodyguard         2011
# ...         ...                          ...          ...
# 781   tt1522329                     Tum Mile         2009
# 302   tt0430589  Shaadi Karke Phas Gaya Yaar         2006
# 301   tt0430480    Popcorn Khao! Mast Ho Jao         2004
# 784   tt1538210              Aao Wish Karein         2009
# 653   tt1227524                    Aashayein         2010
#
#                           genre  \
# 901   Action | Crime | Thriller
# 625              Comedy | Drama
# 32     Action | Drama | Romance
# 1092   Comedy | Drama | Fantasy
# 863                     Romance
# ...                         ...
# 781             Drama | Romance
# ...

# %% [markdown]
# #filter actor name and moviecount

# %%
actor[['actorname','moviecount']]
# Out:
#             actorname  moviecount
# 0          Aamir Khan          11
# 1      Shah Rukh Khan          23
# 2         Salman Khan          36
# 3        Katrina Kaif          17
# 4    Deepika Padukone          16
# ..                ...         ...
# 296       Achint Kaur           4
# 297   Yuvika Chaudhry           5
# 298      Pankaj Berry           5
# 299      Varun Dhawan           0
# 300     Nargis Fakhri           0
#
# [301 rows x 2 columns]

# %% [markdown]
# #check which actor has highest moviecount

# %%
actor_filtered = actor[['actorname','moviecount']]

# %%
actor_filtered.sort_values('moviecount', ascending=False)
# Out:
#              actorname  moviecount
# 18        Akshay Kumar          54
# 14          Ajay Devgn          49
# 11    Amitabh Bachchan          48
# 36         Sanjay Dutt          43
# 83        Sunil Shetty          42
# ..                 ...         ...
# 44   Aditya Roy Kapoor           4
# 157    Manjari Phadnis           4
# 158       Kunal Kapoor           4
# 299       Varun Dhawan           0
# 300      Nargis Fakhri           0
#
# [301 rows x 2 columns]

# %% [markdown]
# #Top actor who has highest movie count

# %%
actor_filtered.sort_values('moviecount', ascending=False).iloc[0]
# Out:
# actorname     Akshay Kumar
# moviecount              54
# Name: 18, dtype: object

# %% [markdown]
# #Top 5 actor who has highest movie count

# %%
actor_filtered.sort_values('moviecount', ascending=False).iloc[0:5]
# Out:
#            actorname  moviecount
# 18      Akshay Kumar          54
# 14        Ajay Devgn          49
# 11  Amitabh Bachchan          48
# 36       Sanjay Dutt          43
# 83      Sunil Shetty          42

# %% [markdown]
# #check which director has highest moviecount

# %%
director_filtered = director[['directorname','moviecount']]

# %%
director_filtered.sort_values('moviecount', ascending=False)
# Out:
#           directorname  moviecount
# 28        Priyadarshan          19
# 31     Ram Gopal Varma          17
# 46        Vikram Bhatt          16
# 17        David Dhawan          11
# 39   Madhur Bhandarkar          10
# ..                 ...         ...
# 73    Dharmesh Darshan           3
# 76       Shashant Shah           3
# 80         Kundan Shah           3
# 83        Rahul Rawail           3
# 117        Puneet Sira           3
#
# [118 rows x 2 columns]

# %% [markdown]
# #Top 5 director who has highest movie count

# %%
director_filtered.sort_values('moviecount', ascending=False).iloc[0:5]
# Out:
#          directorname  moviecount
# 28       Priyadarshan          19
# 31    Ram Gopal Varma          17
# 46       Vikram Bhatt          16
# 17       David Dhawan          11
# 39  Madhur Bhandarkar          10

# %% [markdown]
# #Top director who has highest movie count

# %%
director_filtered.sort_values('moviecount', ascending=False).iloc[0]
# Out:
# directorname    Priyadarshan
# moviecount                19
# Name: 28, dtype: object

# %% [markdown]
# #movie realeased in 2014

# %%
movie2.sort_values('releaseyear', ascending=False)
# Out:
#          imdbid                             title  releaseyear  \
# 1283  tt4228746                               Zid         2014
# 1205  tt3142232                         Heropanti         2014
# 1186  tt2951576                        One by Two         2014
# 1188  tt2976176                           Lakshmi         2014
# 1189  tt2978626                     Entertainment         2014
# ...         ...                               ...          ...
# 38    tt0290326  Tum Bin...: Love Will Find a Way         2001
# 37    tt0289845                               Aks         2001
# 36    tt0288273                            Uljhan         2001
# 34    tt0285319                         Paagalpan         2001
# 0     tt0118578                            Albela         2001
#
#                          genre  \
# 1283                  Thriller
# 1205          Action | Romance
# 1186  Comedy | Drama | Romance
# 1188                     Drama
# 1189                    Comedy
# ...

# %%
movie3 = movie2.sort_values('releaseyear', ascending=False)

# %%
movie4 = movie3[movie3.releaseyear==2014]

# %%
movie4[['title','releaseyear']]
# Out:
#                    title  releaseyear
# 1283                 Zid         2014
# 1205           Heropanti         2014
# 1186          One by Two         2014
# 1188             Lakshmi         2014
# 1189       Entertainment         2014
# ...                  ...          ...
# 1248         Dishkiyaoon         2014
# 1244    Yeh Hai Bakrapur         2014
# 1230              Haider         2014
# 1247  Bhoothnath Returns         2014
# 1231       Daawat-e-Ishq         2014
#
# [92 rows x 2 columns]

# %% [markdown]
# #filtering googleHits of actor and director data

# %%
actor[['actorname','googlehits']]
# Out:
#             actorname  googlehits
# 0          Aamir Khan     2460000
# 1      Shah Rukh Khan     2670000
# 2         Salman Khan     3490000
# 3        Katrina Kaif     2120000
# 4    Deepika Padukone     3000000
# ..                ...         ...
# 296       Achint Kaur           0
# 297   Yuvika Chaudhry           0
# 298      Pankaj Berry           0
# 299      Varun Dhawan           0
# 300     Nargis Fakhri           0
#
# [301 rows x 2 columns]

# %%
director[['directorname','googlehits']]
# Out:
#         directorname  googlehits
# 0    Rajkumar Hirani      146000
# 1         Farah Khan     1060000
# 2        Karan Johar     1050000
# 3         Sajid Khan      905000
# 4       Rohit Shetty      437000
# ..               ...         ...
# 113     Shyam Ramsay        9930
# 114      Jag Mundhra        6710
# 115    Kalpana Lajmi        4380
# 116    Ajay Chandhok        2420
# 117      Puneet Sira        2030
#
# [118 rows x 2 columns]

# %% [markdown]
# #Top 10 googleHits of actor and director data

# %% [markdown]
# Movies per year

# %%
movie
# Out:
#          imdbid                              title  releaseyear  releasedate  \
# 0     tt0118578                             Albela         2001  20 Apr 2001
# 1     tt0169102  Lagaan: Once Upon a Time in India         2001  08 May 2002
# 2     tt0187279           Meri Biwi Ka Jawab Nahin         2004  02 Jul 2004
# 3     tt0222024             Hum Tumhare Hain Sanam         2002  24 May 2002
# 4     tt0227194                         One 2 Ka 4         2001  30 Mar 2001
# ...         ...                                ...          ...          ...
# 1279  tt4121522               Shuruaat Ka Interval         2014  15 Aug 2014
# 1280  tt4187650                   Trip to Bhangarh         2014  28 Aug 2014
# 1281  tt4190220                           Zed Plus         2014  28 Nov 2014
# 1282  tt4219300                    Gollu aur Pappu         2014  21 Nov 2014
# 1283  tt4228746                                Zid         2014  28 Nov 2014
#
#                             genre  \
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(movie.groupby('releaseyear').agg({'title':'count'}))

# %%
movie.groupby('directors').agg({'hitflop':'mean'}).reset_index().sort_values('hitflop', ascending=False)
# Out:
#             directors  hitflop
# 89        Arbaaz Khan      8.0
# 482     Rakesh Roshan      8.0
# 21      Aditya Chopra      8.0
# 616          Siddique      8.0
# 539  Sajid Nadiadwala      8.0
# ..                ...      ...
# 297  Kunal Shivdasani      1.0
# 294  Kunaal Roy Kapur      1.0
# 293         Kumar Raj      1.0
# 292         Kumar Jay      1.0
# 730       Zubair Khan      1.0
#
# [731 rows x 2 columns]

# %%
movie[['directors', 'actors']]
# Out:
#                                               directors  \
# 0                                         Deepak Sareen
# 1                                    Ashutosh Gowariker
# 2                          Pankaj Parashar | S.M. Iqbal
# 3                                         K.S. Adiyaman
# 4                                     Shashilal K. Nair
# ...                                                 ...
# 1279  Aarti S. Bagdi | Amrit Raj Gupta | Krishan Hoo...
# 1280                                     Jitendra Pawar
# 1281                            Chandra Prakash Dwivedi
# 1282                                     Kabir Sadanand
# 1283                     Rohit Malhotra | Anubhav Sinha
#
#                                                  actors
# 0     Govinda | Aishwarya Rai Bachchan | Jackie Shro...
# 1     Aamir Khan | Gracy Singh | Rachel Shelley | Pa...
# 2     Akshay Kumar | Sridevi | Gulshan Grover | Laxm...
# 3     Shah Rukh Khan | Madhuri Dixit | Salman Khan |...
# ...

# %%
movie['actors'] = movie.actors.astype(str)

# %%
new_series = movie.actors.apply(lambda x: x.split(' | '))

# %%
actors_split = pd.DataFrame(new_series.tolist(), columns = ['actor0', 'actor1', 'actor2', 'actor3'])
actors_split.head()
# Out:
#            actor0                  actor1          actor2             actor3
# 0         Govinda  Aishwarya Rai Bachchan   Jackie Shroff  Namrata Shirodkar
# 1      Aamir Khan             Gracy Singh  Rachel Shelley   Paul Blackthorne
# 2    Akshay Kumar                 Sridevi  Gulshan Grover    Laxmikant Berde
# 3  Shah Rukh Khan           Madhuri Dixit     Salman Khan     Atul Agnihotri
# 4  Shah Rukh Khan             Juhi Chawla   Jackie Shroff      Nirmal Pandey

# %%
movie5 = pd.concat([movie[['title', 'directors']], actors_split], axis = 1)

# %%
actors_split.to_csv("actors_split.csv")

# %%
movie5
# Out:
#                                   title  \
# 0                                Albela
# 1     Lagaan: Once Upon a Time in India
# 2              Meri Biwi Ka Jawab Nahin
# 3                Hum Tumhare Hain Sanam
# 4                            One 2 Ka 4
# ...                                 ...
# 1279               Shuruaat Ka Interval
# 1280                   Trip to Bhangarh
# 1281                           Zed Plus
# 1282                    Gollu aur Pappu
# 1283                                Zid
#
#                                               directors            actor0  \
# 0                                         Deepak Sareen           Govinda
# 1                                    Ashutosh Gowariker        Aamir Khan
# 2                          Pankaj Parashar | S.M. Iqbal      Akshay Kumar
# 3                                         K.S. Adiyaman    Shah Rukh Khan
# 4                                     Shashilal K. Nair    Shah Rukh Khan
# ...

# %%
movie6 = movie5[['directors','actor0']]

# %%
movie6
# Out:
#                                               directors            actor0
# 0                                         Deepak Sareen           Govinda
# 1                                    Ashutosh Gowariker        Aamir Khan
# 2                          Pankaj Parashar | S.M. Iqbal      Akshay Kumar
# 3                                         K.S. Adiyaman    Shah Rukh Khan
# 4                                     Shashilal K. Nair    Shah Rukh Khan
# ...                                                 ...               ...
# 1279  Aarti S. Bagdi | Amrit Raj Gupta | Krishan Hoo...   Kaivalya Chheda
# 1280                                     Jitendra Pawar  Manish Choudhary
# 1281                            Chandra Prakash Dwivedi      Adil Hussain
# 1282                                     Kabir Sadanand           Vir Das
# 1283                     Rohit Malhotra | Anubhav Sinha       Shradha Das
#
# [1284 rows x 2 columns]

# %%
movie6[movie6.actor0==Govinda]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\AKSHAY~1\AppData\Local\Temp/ipykernel_20256/1497168662.py in <module>
# ----> 1 movie6[movie6.actor0==Govinda]
#
# NameError: name 'Govinda' is not defined

# %%
'movie5.groupby('directors').sort_values('actor0==Akshay Kumar')

# %%
movie6
